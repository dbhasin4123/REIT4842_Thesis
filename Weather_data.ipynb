# %%
import h5py

# Open the HDF5 file
with h5py.File('deven_wind.h5', 'r') as f:
    # Print all top-level groups/datasets
    def printname(name):
        print(name)
    f.visit(printname)
# Out:
# data
# data/18116
# data/18116/windspeed-aws_instant_30minute
# data/18116/windspeed-aws_instant_30minute/_i_table
# data/18116/windspeed-aws_instant_30minute/_i_table/index
# data/18116/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/18116/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/18116/windspeed-aws_instant_30minute/_i_table/index/indices
# data/18116/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/18116/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/18116/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/18116/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/18116/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/18116/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/18116/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/18116/windspeed-aws_instant_30minute/table
# data/18116/windspeed-synoptic_instant_3hour
# data/18116/windspeed-synoptic_instant_3hour/_i_table
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/18116/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/18116/windspeed-synoptic_instant_3hour/table
# data/18201
# data/18201/windspeed-aws_instant_30minute
# data/18201/windspeed-aws_instant_30minute/_i_table
# data/18201/windspeed-aws_instant_30minute/_i_table/index
# data/18201/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/18201/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/18201/windspeed-aws_instant_30minute/_i_table/index/indices
# data/18201/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/18201/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/18201/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/18201/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/18201/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/18201/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/18201/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/18201/windspeed-aws_instant_30minute/table
# data/18201/windspeed-synoptic_instant_3hour
# data/18201/windspeed-synoptic_instant_3hour/_i_table
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/18201/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/18201/windspeed-synoptic_instant_3hour/table
# data/19062
# data/19062/windspeed-synoptic_instant_3hour
# data/19062/windspeed-synoptic_instant_3hour/_i_table
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/19062/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/19062/windspeed-synoptic_instant_3hour/table
# data/21131
# data/21131/windspeed-aws_instant_30minute
# data/21131/windspeed-aws_instant_30minute/_i_table
# data/21131/windspeed-aws_instant_30minute/_i_table/index
# data/21131/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/21131/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/21131/windspeed-aws_instant_30minute/_i_table/index/indices
# data/21131/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/21131/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/21131/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/21131/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/21131/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/21131/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/21131/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/21131/windspeed-aws_instant_30minute/table
# data/21131/windspeed-synoptic_instant_3hour
# data/21131/windspeed-synoptic_instant_3hour/_i_table
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/21131/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/21131/windspeed-synoptic_instant_3hour/table
# data/21133
# data/21133/windspeed-aws_instant_30minute
# data/21133/windspeed-aws_instant_30minute/_i_table
# data/21133/windspeed-aws_instant_30minute/_i_table/index
# data/21133/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/21133/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/21133/windspeed-aws_instant_30minute/_i_table/index/indices
# data/21133/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/21133/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/21133/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/21133/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/21133/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/21133/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/21133/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/21133/windspeed-aws_instant_30minute/table
# data/21133/windspeed-synoptic_instant_3hour
# data/21133/windspeed-synoptic_instant_3hour/_i_table
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/21133/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/21133/windspeed-synoptic_instant_3hour/table
# data/22046
# data/22046/windspeed-aws_instant_30minute
# data/22046/windspeed-aws_instant_30minute/_i_table
# data/22046/windspeed-aws_instant_30minute/_i_table/index
# data/22046/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/22046/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/22046/windspeed-aws_instant_30minute/_i_table/index/indices
# data/22046/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/22046/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/22046/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/22046/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/22046/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/22046/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/22046/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/22046/windspeed-aws_instant_30minute/table
# data/22046/windspeed-synoptic_instant_3hour
# data/22046/windspeed-synoptic_instant_3hour/_i_table
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/22046/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/22046/windspeed-synoptic_instant_3hour/table
# data/24511
# data/24511/windspeed-synoptic_instant_3hour
# data/24511/windspeed-synoptic_instant_3hour/_i_table
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/24511/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/24511/windspeed-synoptic_instant_3hour/table
# data/30022
# data/30022/windspeed-aws_instant_30minute
# data/30022/windspeed-aws_instant_30minute/_i_table
# data/30022/windspeed-aws_instant_30minute/_i_table/index
# data/30022/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/30022/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/30022/windspeed-aws_instant_30minute/_i_table/index/indices
# data/30022/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/30022/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/30022/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/30022/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/30022/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/30022/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/30022/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/30022/windspeed-aws_instant_30minute/table
# data/30022/windspeed-synoptic_instant_3hour
# data/30022/windspeed-synoptic_instant_3hour/_i_table
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/30022/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/30022/windspeed-synoptic_instant_3hour/table
# data/32037
# data/32037/windspeed-aws_instant_30minute
# data/32037/windspeed-aws_instant_30minute/_i_table
# data/32037/windspeed-aws_instant_30minute/_i_table/index
# data/32037/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/32037/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/32037/windspeed-aws_instant_30minute/_i_table/index/indices
# data/32037/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/32037/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/32037/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/32037/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/32037/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/32037/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/32037/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/32037/windspeed-aws_instant_30minute/table
# data/32037/windspeed-synoptic_instant_3hour
# data/32037/windspeed-synoptic_instant_3hour/_i_table
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/32037/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/32037/windspeed-synoptic_instant_3hour/table
# data/40922
# data/40922/windspeed-aws_instant_30minute
# data/40922/windspeed-aws_instant_30minute/_i_table
# data/40922/windspeed-aws_instant_30minute/_i_table/index
# data/40922/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/40922/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/40922/windspeed-aws_instant_30minute/_i_table/index/indices
# data/40922/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/40922/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/40922/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/40922/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/40922/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/40922/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/40922/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/40922/windspeed-aws_instant_30minute/table
# data/40922/windspeed-synoptic_instant_3hour
# data/40922/windspeed-synoptic_instant_3hour/_i_table
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/40922/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/40922/windspeed-synoptic_instant_3hour/table
# data/42112
# data/42112/windspeed-aws_instant_30minute
# data/42112/windspeed-aws_instant_30minute/_i_table
# data/42112/windspeed-aws_instant_30minute/_i_table/index
# data/42112/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/42112/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/42112/windspeed-aws_instant_30minute/_i_table/index/indices
# data/42112/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/42112/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/42112/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/42112/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/42112/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/42112/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/42112/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/42112/windspeed-aws_instant_30minute/table
# data/42112/windspeed-synoptic_instant_3hour
# data/42112/windspeed-synoptic_instant_3hour/_i_table
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/42112/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/42112/windspeed-synoptic_instant_3hour/table
# data/56243
# data/56243/windspeed-aws_instant_30minute
# data/56243/windspeed-aws_instant_30minute/_i_table
# data/56243/windspeed-aws_instant_30minute/_i_table/index
# data/56243/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/56243/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/56243/windspeed-aws_instant_30minute/_i_table/index/indices
# data/56243/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/56243/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/56243/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/56243/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/56243/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/56243/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/56243/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/56243/windspeed-aws_instant_30minute/table
# data/56243/windspeed-synoptic_instant_3hour
# data/56243/windspeed-synoptic_instant_3hour/_i_table
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/56243/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/56243/windspeed-synoptic_instant_3hour/table
# data/62101
# data/62101/windspeed-aws_instant_30minute
# data/62101/windspeed-aws_instant_30minute/_i_table
# data/62101/windspeed-aws_instant_30minute/_i_table/index
# data/62101/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/62101/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/62101/windspeed-aws_instant_30minute/_i_table/index/indices
# data/62101/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/62101/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/62101/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/62101/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/62101/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/62101/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/62101/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/62101/windspeed-aws_instant_30minute/table
# data/62101/windspeed-synoptic_instant_3hour
# data/62101/windspeed-synoptic_instant_3hour/_i_table
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/62101/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/62101/windspeed-synoptic_instant_3hour/table
# data/70217
# data/70217/windspeed-aws_instant_30minute
# data/70217/windspeed-aws_instant_30minute/_i_table
# data/70217/windspeed-aws_instant_30minute/_i_table/index
# data/70217/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/70217/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/70217/windspeed-aws_instant_30minute/_i_table/index/indices
# data/70217/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/70217/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/70217/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/70217/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/70217/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/70217/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/70217/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/70217/windspeed-aws_instant_30minute/table
# data/70217/windspeed-synoptic_instant_3hour
# data/70217/windspeed-synoptic_instant_3hour/_i_table
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/70217/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/70217/windspeed-synoptic_instant_3hour/table
# data/70330
# data/70330/windspeed-aws_instant_30minute
# data/70330/windspeed-aws_instant_30minute/_i_table
# data/70330/windspeed-aws_instant_30minute/_i_table/index
# data/70330/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/70330/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/70330/windspeed-aws_instant_30minute/_i_table/index/indices
# data/70330/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/70330/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/70330/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/70330/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/70330/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/70330/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/70330/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/70330/windspeed-aws_instant_30minute/table
# data/70330/windspeed-synoptic_instant_3hour
# data/70330/windspeed-synoptic_instant_3hour/_i_table
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/70330/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/70330/windspeed-synoptic_instant_3hour/table
# data/73138
# data/73138/windspeed-aws_instant_30minute
# data/73138/windspeed-aws_instant_30minute/_i_table
# data/73138/windspeed-aws_instant_30minute/_i_table/index
# data/73138/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/73138/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/73138/windspeed-aws_instant_30minute/_i_table/index/indices
# data/73138/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/73138/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/73138/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/73138/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/73138/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/73138/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/73138/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/73138/windspeed-aws_instant_30minute/table
# data/73138/windspeed-synoptic_instant_3hour
# data/73138/windspeed-synoptic_instant_3hour/_i_table
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/73138/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/73138/windspeed-synoptic_instant_3hour/table
# data/78018
# data/78018/windspeed-aws_instant_30minute
# data/78018/windspeed-aws_instant_30minute/_i_table
# data/78018/windspeed-aws_instant_30minute/_i_table/index
# data/78018/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/78018/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/78018/windspeed-aws_instant_30minute/_i_table/index/indices
# data/78018/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/78018/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/78018/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/78018/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/78018/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/78018/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/78018/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/78018/windspeed-aws_instant_30minute/table
# data/78018/windspeed-synoptic_instant_3hour
# data/78018/windspeed-synoptic_instant_3hour/_i_table
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/78018/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/78018/windspeed-synoptic_instant_3hour/table
# data/79101
# data/79101/windspeed-aws_instant_30minute
# data/79101/windspeed-aws_instant_30minute/_i_table
# data/79101/windspeed-aws_instant_30minute/_i_table/index
# data/79101/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/79101/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/79101/windspeed-aws_instant_30minute/_i_table/index/indices
# data/79101/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/79101/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/79101/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/79101/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/79101/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/79101/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/79101/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/79101/windspeed-aws_instant_30minute/table
# data/79101/windspeed-synoptic_instant_3hour
# data/79101/windspeed-synoptic_instant_3hour/_i_table
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/79101/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/79101/windspeed-synoptic_instant_3hour/table
# data/85099
# data/85099/windspeed-aws_instant_30minute
# data/85099/windspeed-aws_instant_30minute/_i_table
# data/85099/windspeed-aws_instant_30minute/_i_table/index
# data/85099/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/85099/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/85099/windspeed-aws_instant_30minute/_i_table/index/indices
# data/85099/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/85099/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/85099/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/85099/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/85099/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/85099/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/85099/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/85099/windspeed-aws_instant_30minute/table
# data/85099/windspeed-synoptic_instant_3hour
# data/85099/windspeed-synoptic_instant_3hour/_i_table
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/85099/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/85099/windspeed-synoptic_instant_3hour/table
# data/86127
# data/86127/windspeed-synoptic_instant_3hour
# data/86127/windspeed-synoptic_instant_3hour/_i_table
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/86127/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/86127/windspeed-synoptic_instant_3hour/table
# data/89002
# data/89002/windspeed-aws_instant_30minute
# data/89002/windspeed-aws_instant_30minute/_i_table
# data/89002/windspeed-aws_instant_30minute/_i_table/index
# data/89002/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/89002/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/89002/windspeed-aws_instant_30minute/_i_table/index/indices
# data/89002/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/89002/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/89002/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/89002/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/89002/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/89002/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/89002/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/89002/windspeed-aws_instant_30minute/table
# data/89002/windspeed-synoptic_instant_3hour
# data/89002/windspeed-synoptic_instant_3hour/_i_table
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/89002/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/89002/windspeed-synoptic_instant_3hour/table
# data/89085
# data/89085/windspeed-synoptic_instant_3hour
# data/89085/windspeed-synoptic_instant_3hour/_i_table
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/89085/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/89085/windspeed-synoptic_instant_3hour/table
# data/89112
# data/89112/windspeed-aws_instant_30minute
# data/89112/windspeed-aws_instant_30minute/_i_table
# data/89112/windspeed-aws_instant_30minute/_i_table/index
# data/89112/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/89112/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/89112/windspeed-aws_instant_30minute/_i_table/index/indices
# data/89112/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/89112/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/89112/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/89112/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/89112/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/89112/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/89112/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/89112/windspeed-aws_instant_30minute/table
# data/89112/windspeed-synoptic_instant_3hour
# data/89112/windspeed-synoptic_instant_3hour/_i_table
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/89112/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/89112/windspeed-synoptic_instant_3hour/table
# data/90035
# data/90035/windspeed-aws_instant_30minute
# data/90035/windspeed-aws_instant_30minute/_i_table
# data/90035/windspeed-aws_instant_30minute/_i_table/index
# data/90035/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/90035/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/90035/windspeed-aws_instant_30minute/_i_table/index/indices
# data/90035/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/90035/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/90035/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/90035/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/90035/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/90035/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/90035/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/90035/windspeed-aws_instant_30minute/table
# data/90035/windspeed-synoptic_instant_3hour
# data/90035/windspeed-synoptic_instant_3hour/_i_table
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/90035/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/90035/windspeed-synoptic_instant_3hour/table
# data/90175
# data/90175/windspeed-aws_instant_30minute
# data/90175/windspeed-aws_instant_30minute/_i_table
# data/90175/windspeed-aws_instant_30minute/_i_table/index
# data/90175/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/90175/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/90175/windspeed-aws_instant_30minute/_i_table/index/indices
# data/90175/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/90175/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/90175/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/90175/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/90175/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/90175/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/90175/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/90175/windspeed-aws_instant_30minute/table
# data/90175/windspeed-synoptic_instant_3hour
# data/90175/windspeed-synoptic_instant_3hour/_i_table
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/90175/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/90175/windspeed-synoptic_instant_3hour/table
# data/90176
# data/90176/windspeed-aws_instant_30minute
# data/90176/windspeed-aws_instant_30minute/_i_table
# data/90176/windspeed-aws_instant_30minute/_i_table/index
# data/90176/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/90176/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/90176/windspeed-aws_instant_30minute/_i_table/index/indices
# data/90176/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/90176/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/90176/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/90176/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/90176/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/90176/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/90176/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/90176/windspeed-aws_instant_30minute/table
# data/90176/windspeed-synoptic_instant_3hour
# data/90176/windspeed-synoptic_instant_3hour/_i_table
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/90176/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/90176/windspeed-synoptic_instant_3hour/table
# data/91245
# data/91245/windspeed-aws_instant_30minute
# data/91245/windspeed-aws_instant_30minute/_i_table
# data/91245/windspeed-aws_instant_30minute/_i_table/index
# data/91245/windspeed-aws_instant_30minute/_i_table/index/abounds
# data/91245/windspeed-aws_instant_30minute/_i_table/index/bounds
# data/91245/windspeed-aws_instant_30minute/_i_table/index/indices
# data/91245/windspeed-aws_instant_30minute/_i_table/index/indicesLR
# data/91245/windspeed-aws_instant_30minute/_i_table/index/mbounds
# data/91245/windspeed-aws_instant_30minute/_i_table/index/mranges
# data/91245/windspeed-aws_instant_30minute/_i_table/index/ranges
# data/91245/windspeed-aws_instant_30minute/_i_table/index/sorted
# data/91245/windspeed-aws_instant_30minute/_i_table/index/sortedLR
# data/91245/windspeed-aws_instant_30minute/_i_table/index/zbounds
# data/91245/windspeed-aws_instant_30minute/table
# data/91245/windspeed-synoptic_instant_3hour
# data/91245/windspeed-synoptic_instant_3hour/_i_table
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/abounds
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/bounds
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/indices
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/indicesLR
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/mbounds
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/mranges
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/ranges
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/sorted
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/sortedLR
# data/91245/windspeed-synoptic_instant_3hour/_i_table/index/zbounds
# data/91245/windspeed-synoptic_instant_3hour/table
# metadata
# metadata/data-request
# metadata/data-request/_i_table
# metadata/data-request/_i_table/index
# metadata/data-request/_i_table/index/abounds
# metadata/data-request/_i_table/index/bounds
# metadata/data-request/_i_table/index/indices
# metadata/data-request/_i_table/index/indicesLR
# metadata/data-request/_i_table/index/mbounds
# metadata/data-request/_i_table/index/mranges
# metadata/data-request/_i_table/index/ranges
# metadata/data-request/_i_table/index/sorted
# metadata/data-request/_i_table/index/sortedLR
# metadata/data-request/_i_table/index/zbounds
# metadata/data-request/table
# metadata/date
# metadata/date/index
# metadata/date/values

# %%
import h5py
import pandas as pd

file_path = 'deven_wind.h5'

with h5py.File(file_path, 'r') as f:
    # Navigate to the core datasets
    airtemp_30min = f['data/42112/airtemp-aws_instant_30minute/table'][:]
    airtemp_3hour = f['data/42112/airtemp-thp_instant_3hour/table'][:]
    rh_30min = f['data/42112/relativehumidity-aws_instant_30minute/table'][:]
    rh_3hour = f['data/42112/relativehumidity-thp_instant_3hour/table'][:]

    # Print shape and dtype to understand structure
    print("Air Temp 30min:", airtemp_30min.shape, airtemp_30min.dtype)
    print("Air Temp 3hour:", airtemp_3hour.shape, airtemp_3hour.dtype)
    print("RH 30min:", rh_30min.shape, rh_30min.dtype)
    print("RH 3hour:", rh_3hour.shape, rh_3hour.dtype)
# Out:
# Air Temp 30min: (6815,) [('index', '<i8'), ('values_block_0', '<f8', (1,)), ('values_block_1', 'S3', (1,))]
# Air Temp 3hour: (1124,) [('index', '<i8'), ('values_block_0', '<f8', (1,)), ('values_block_1', 'S1', (1,))]
# RH 30min: (6815,) [('index', '<i8'), ('values_block_0', '<f8', (1,)), ('values_block_1', 'S3', (1,))]
# RH 3hour: (1124,) [('index', '<i8'), ('values_block_0', '<f8', (1,)), ('values_block_1', 'S1', (1,))]

# %%
import h5py
import pandas as pd

file_path = "deven_wind.h5"

with h5py.File(file_path, 'r') as f:
    data = f['data/40922/windspeed-aws_instant_30minute/table'][:]

# Convert to DataFrame
df_airtemp_3hour = pd.DataFrame({
    'timestamp_ns': data['index'],
    'windspeed': data['values_block_0'].flatten(),
    'flag': [x.decode('utf-8') for x in data['values_block_1'].flatten()]
})

# Convert nanosecond timestamps to datetime
df_airtemp_3hour['time'] = pd.to_datetime(df_airtemp_3hour['timestamp_ns'], unit='ns')

# View first few rows
df_airtemp_3hour.head()
# Out:
#           timestamp_ns  windspeed flag                time
# 0  1672531200000000000   4.611111    N 2023-01-01 00:00:00
# 1  1672533000000000000   4.111111    N 2023-01-01 00:30:00
# 2  1672534800000000000   4.111111    N 2023-01-01 01:00:00
# 3  1672536600000000000   3.611111    N 2023-01-01 01:30:00
# 4  1672538400000000000   4.611111    N 2023-01-01 02:00:00

# %%
import h5py
import pandas as pd

# Step 1: Load the HDF5 file
file_path = "deven_wind.h5"  # Update this path if needed

with h5py.File(file_path, 'r') as f:
    data = f['data/40922/windspeed-aws_instant_30minute/table'][:]

# Step 2: Convert to DataFrame
df_airtemp_3hour = pd.DataFrame({
    'timestamp_ns': data['index'],
    'windspeed': data['values_block_0'].flatten(),
    'flag': [x.decode('utf-8') for x in data['values_block_1'].flatten()]
})

# Step 3: Convert nanosecond timestamps to datetime and extract date
df_airtemp_3hour['time'] = pd.to_datetime(df_airtemp_3hour['timestamp_ns'], unit='ns')
df_airtemp_3hour['date'] = df_airtemp_3hour['time'].dt.date

# Step 4: Aggregate by date to get max/min temperatures
daily_summary = df_airtemp_3hour.groupby('date').agg(
    max_temp=('windspeed', 'max'),
    min_temp=('windspeed', 'min')
).reset_index()

# Step 5: Export to Excel
output_file = "windspeed_3hour_daily_summary.xlsx"
daily_summary.to_excel(output_file, sheet_name="QLD1", index=False)

print(f"Saved daily summary to {output_file}")
# Out:
# Saved daily summary to windspeed_3hour_daily_summary.xlsx

# %%
print("Earliest date:", df_airtemp_3hour['time'].min())
print("Latest date:", df_airtemp_3hour['time'].max())
# Out:
# Earliest date: 2023-01-01 00:00:00
# Latest date: 2023-05-22 23:00:00

# %%
import h5py
import numpy as np
from datetime import datetime
import pandas as pd

def find_station_with_longest_airtemp_record(filename):
    """
    Scans through an H5 file to find the BOM station with the longest
    historical record for airtemp-thp_instant_3hour data.
    
    Args:
        filename (str): Path to the H5 file
        
    Returns:
        tuple: (station_id, start_date, end_date, duration_in_days, df)
    """
    longest_duration = 0
    longest_station_id = None
    longest_start_date = None
    longest_end_date = None
    longest_df = None
    station_data = {}
    
    with h5py.File(filename, 'r') as h5file:
        # Get all station IDs (directories under 'data')
        station_ids = []
        if 'data' in h5file:
            station_ids = list(h5file['data'].keys())
        else:
            # Search for station IDs at the root level
            station_ids = [key for key in h5file.keys() if isinstance(h5file[key], h5py.Group)]
        
        print(f"Found {len(station_ids)} stations in the H5 file")
        
        # Check each station for airtemp-thp_instant_3hour data
        for station_id in station_ids:
            try:
                # Path to the table with temperature data
                path = f"data/{station_id}/airtemp-thp_instant_3hour/table"
                
                # Alternative path if the structure is different
                if path not in h5file:
                    path = f"{station_id}/airtemp-thp_instant_3hour/table"
                    if path not in h5file:
                        continue
                
                # Get the dataset
                dataset = h5file[path]
                
                # Get column names
                column_names = dataset.dtype.names
                print(f"Station {station_id} columns: {column_names}")
                
                # Look for time-related columns based on the sample data
                # First try specific columns we know about
                date_col = None
                timestamp_col = None
                temp_col = None
                flag_col = None
                
                # Check for the timestamp_ns column (from sample data)
                if 'timestamp_ns' in column_names:
                    timestamp_col = 'timestamp_ns'
                else:
                    # Look for any timestamp column
                    timestamp_candidates = [col for col in column_names if 'timestamp' in col.lower()]
                    if timestamp_candidates:
                        timestamp_col = timestamp_candidates[0]
                
                # Check for the formatted time column
                time_candidates = [col for col in column_names if 'time' in col.lower() and not 'timestamp' in col.lower()]
                if time_candidates:
                    date_col = time_candidates[0]
                
                # Look for temperature column
                temp_candidates = [col for col in column_names if 'temp' in col.lower() or 'air' in col.lower()]
                if temp_candidates:
                    temp_col = temp_candidates[0]
                
                # Look for flag column
                flag_candidates = [col for col in column_names if 'flag' in col.lower()]
                if flag_candidates:
                    flag_col = flag_candidates[0]
                
                # If we don't have a date or timestamp column, we can't process this station
                if not (date_col or timestamp_col):
                    print(f"Station {station_id}: No time column found")
                    continue
                
                # Create a dataframe from the dataset
                df = pd.DataFrame()
                
                # Extract data based on available columns
                if timestamp_col:
                    timestamp_data = dataset[timestamp_col][:]
                    # Convert nanosecond timestamps to datetime
                    df['timestamp'] = pd.to_datetime(timestamp_data, unit='ns')
                
                if date_col:
                    date_data = dataset[date_col][:]
                    # Convert to strings if they're not already
                    if date_data.dtype.kind == 'S':  # bytes strings
                        date_strings = [d.decode('utf-8') for d in date_data]
                    else:
                        date_strings = date_data
                    
                    # Try to parse the dates
                    try:
                        df['formatted_time'] = pd.to_datetime(date_strings)
                    except:
                        print(f"Station {station_id}: Could not parse date strings")
                
                # Use either parsed datetime or timestamp for date range calculation
                if 'formatted_time' in df.columns:
                    dates = df['formatted_time']
                elif 'timestamp' in df.columns:
                    dates = df['timestamp']
                else:
                    print(f"Station {station_id}: No usable date column")
                    continue
                
                # Extract temperature and flag data if available
                if temp_col:
                    df['temperature'] = dataset[temp_col][:]
                
                if flag_col:
                    df['flag'] = dataset[flag_col][:]
                
                # Get start and end dates
                start_date = min(dates)
                end_date = max(dates)
                
                # Calculate the duration in days
                duration = (end_date - start_date).total_seconds() / (24 * 3600)
                
                # Store the result for this station
                station_data[station_id] = {
                    'start_date': start_date,
                    'end_date': end_date,
                    'duration_days': duration,
                    'record_count': len(dates)
                }
                
                # Update if this is the longest record so far
                if duration > longest_duration:
                    longest_duration = duration
                    longest_station_id = station_id
                    longest_start_date = start_date
                    longest_end_date = end_date
                    longest_df = df.copy()
                
                print(f"Station {station_id}: {start_date} to {end_date} ({duration:.2f} days, {len(dates)} records)")
                
            except Exception as e:
                print(f"Error processing station {station_id}: {str(e)}")
    
    # Create a summary dataframe
    if station_data:
        df = pd.DataFrame.from_dict(
            {k: {
                'start_date': v['start_date'],
                'end_date': v['end_date'],
                'duration_days': v['duration_days'],
                'record_count': v['record_count']
            } for k, v in station_data.items()
        }, orient='index')
        
        # Sort by duration (longest first)
        df = df.sort_values('duration_days', ascending=False)
        print("\nAll stations with airtemp-thp_instant_3hour data, sorted by duration:")
        print(df)
    
    return longest_station_id, longest_start_date, longest_end_date, longest_duration, longest_df

def extract_station_temperature_data(filename, station_id):
    """
    Extracts the temperature data for a specific station from the H5 file
    and saves it to a CSV file.
    
    Args:
        filename (str): Path to the H5 file
        station_id (str): ID of the station to extract data for
        
    Returns:
        DataFrame: The extracted temperature data
    """
    with h5py.File(filename, 'r') as h5file:
        # Path to the table with temperature data
        path = f"data/{station_id}/airtemp-thp_instant_3hour/table"
        
        # Alternative path if the structure is different
        if path not in h5file:
            path = f"{station_id}/airtemp-thp_instant_3hour/table"
            if path not in h5file:
                print(f"Error: airtemp-thp_instant_3hour data not found for station {station_id}")
                return None
        
        # Get the dataset
        dataset = h5file[path]
        column_names = dataset.dtype.names
        print(f"Available columns for station {station_id}: {column_names}")
        
        # Create a dataframe to hold all data
        df = pd.DataFrame()
        
        # Copy all columns to the dataframe
        for col in column_names:
            df[col] = dataset[col][:]
            
        # Look for timestamp columns
        timestamp_col = next((col for col in column_names if 'timestamp' in col.lower()), None)
        if timestamp_col:
            df['datetime'] = pd.to_datetime(df[timestamp_col], unit='ns')
        
        # Look for formatted time columns
        time_col = next((col for col in column_names if 'time' in col.lower() and 'timestamp' not in col.lower()), None)
        if time_col:
            if df[time_col].dtype.kind == 'S':  # If it's a bytes string
                df['formatted_time'] = [t.decode('utf-8') if isinstance(t, bytes) else t for t in df[time_col]]
            else:
                df['formatted_time'] = df[time_col]
        
        # Look for temperature column
        temp_col = next((col for col in column_names if 'temp' in col.lower() or 'air' in col.lower()), None)
        if temp_col:
            df['temperature'] = df[temp_col]
        
        # Save to CSV
        csv_filename = f"station_{station_id}_airtemp_thp_instant_3hour.csv"
        df.to_csv(csv_filename, index=False)
        print(f"Saved temperature data for station {station_id} to {csv_filename}")
        
        return df

if __name__ == "__main__":
    h5_file = "deven_solar.h5"  # Change this to your file path
    
    station_id, start, end, duration, df = find_station_with_longest_airtemp_record(h5_file)
    
    if station_id:
        print("\n===== Result =====")
        print(f"Station with longest airtemp-thp_instant_3hour record: {station_id}")
        print(f"Date range: {start} to {end}")
        print(f"Duration: {duration:.2f} days ({duration/365.25:.2f} years)")
        
        # Extract and save the data for this station
        print("\nExtracting data for the station with the longest record...")
        extract_station_temperature_data(h5_file, station_id)
    else:
        print("No stations with airtemp-thp_instant_3hour data found")
# Out:
# Found 37 stations in the H5 file
# Station 23885 columns: ('index', 'values_block_0', 'values_block_1')
# Station 23885: No time column found
# Station 24511 columns: ('index', 'values_block_0', 'values_block_1')
# Station 24511: No time column found
# Station 24584 columns: ('index', 'values_block_0', 'values_block_1')
# Station 24584: No time column found
# Station 30022 columns: ('index', 'values_block_0', 'values_block_1')
# Station 30022: No time column found
# Station 32195 columns: ('index', 'values_block_0', 'values_block_1')
# Station 32195: No time column found
# Station 33002 columns: ('index', 'values_block_0', 'values_block_1')
# Station 33002: No time column found
# Station 33327 columns: ('index', 'values_block_0', 'values_block_1')
# Station 33327: No time column found
# Station 34035 columns: ('index', 'values_block_0', 'values_block_1')
# Station 34035: No time column found
# Station 35134 columns: ('index', 'values_block_0', 'values_block_1')
# Station 35134: No time column found
# Station 36031 columns: ('index', 'values_block_0', 'values_block_1')
# Station 36031: No time column found
# Station 39089 columns: ('index', 'values_block_0', 'values_block_1')
# Station 39089: No time column found
# Station 40093 columns: ('index', 'values_block_0', 'values_block_1')
# Station 40093: No time column found
# Station 40126 columns: ('index', 'values_block_0', 'values_block_1')
# Station 40126: No time column found
# Station 41359 columns: ('index', 'values_block_0', 'values_block_1')
# Station 41359: No time column found
# Station 41522 columns: ('index', 'values_block_0', 'values_block_1')
# Station 41522: No time column found
# Station 41525 columns: ('index', 'values_block_0', 'values_block_1')
# Station 41525: No time column found
# Station 42112 columns: ('index', 'values_block_0', 'values_block_1')
# Station 42112: No time column found
# Station 50017 columns: ('index', 'values_block_0', 'values_block_1')
# Station 50017: No time column found
# Station 51049 columns: ('index', 'values_block_0', 'values_block_1')
# Station 51049: No time column found
# Station 51164 columns: ('index', 'values_block_0', 'values_block_1')
# Station 51164: No time column found
# Station 55202 columns: ('index', 'values_block_0', 'values_block_1')
# Station 55202: No time column found
# Station 56238 columns: ('index', 'values_block_0', 'values_block_1')
# Station 56238: No time column found
# Station 56243 columns: ('index', 'values_block_0', 'values_block_1')
# Station 56243: No time column found
# Station 62101 columns: ('index', 'values_block_0', 'values_block_1')
# Station 62101: No time column found
# Station 65070 columns: ('index', 'values_block_0', 'values_block_1')
# Station 65070: No time column found
# Station 65103 columns: ('index', 'values_block_0', 'values_block_1')
# Station 65103: No time column found
# Station 70330 columns: ('index', 'values_block_0', 'values_block_1')
# Station 70330: No time column found
# Station 72150 columns: ('index', 'values_block_0', 'values_block_1')
# Station 72150: No time column found
# Station 73151 columns: ('index', 'values_block_0', 'values_block_1')
# Station 73151: No time column found
# Station 74037 columns: ('index', 'values_block_0', 'values_block_1')
# Station 74037: No time column found
# Station 75032 columns: ('index', 'values_block_0', 'values_block_1')
# Station 75032: No time column found
# Station 76031 columns: ('index', 'values_block_0', 'values_block_1')
# Station 76031: No time column found
# Station 76047 columns: ('index', 'values_block_0', 'values_block_1')
# Station 76047: No time column found
# Station 80023 columns: ('index', 'values_block_0', 'values_block_1')
# Station 80023: No time column found
# Station 82039 columns: ('index', 'values_block_0', 'values_block_1')
# Station 82039: No time column found
# Station 82138 columns: ('index', 'values_block_0', 'values_block_1')
# Station 82138: No time column found
# Station 82170 columns: ('index', 'values_block_0', 'values_block_1')
# Station 82170: No time column found
# No stations with airtemp-thp_instant_3hour data found
